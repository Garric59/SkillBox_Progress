# %% [markdown]
# # Циклы. Домашнее задание
#
# ###Цели задания
# Закрепить на практике применение циклов for, while и использование команд break, continue, pass.
#
# ###Что нужно сделать
# Скачайте файл с заданием, откройте его через Jupyter Notebook и выполните задачи.
#
# ###Что оценивается
# Для каждой задачи:
# - программа выполняет все требуемые действия;
# - результаты вычислений и операций корректны;
# - вывод производится в том виде, который описан в задаче;
# - переменные названы информативно.
#
# ### Как отправить задание на проверку
# Выполните задачи, сохраните изменения при помощи опции Save and Checkpoint из вкладки меню File или кнопки Save and Checkpoint на панели инструментов. Отправьте через форму ниже итоговый файл Jupyter Notebook .ipynb или ссылку на него.

# %% [markdown]
# 1. Напишите цикл, который выводит на печать все високосные годы, начиная с 2020 и заканчивая 2050.

# %%
for year in range(2020, 2051, 1):
    if year % 4 ==0:
        print("Високосный год: ", year)
# Out:
# Високосный год:  2020
# Високосный год:  2024
# Високосный год:  2028
# Високосный год:  2032
# Високосный год:  2036
# Високосный год:  2040
# Високосный год:  2044
# Високосный год:  2048

# %% [markdown]
# 2. Студент Джонсон поступил в университет и взял кредит на 120 тысяч долларов под 6% годовых. Все шесть лет учёбы в бакалавриате и магистратуре он не сможет выплачивать кредит и процент будет прибавляться к основному кредиту. Напишите программу, которая посчитает, сколько студент Джонсон должен будет банку к концу своего обучения.

# %%
# Начальная сумма
loan = 120000
procent = 1.06
for i  in range(1, 7):
    loan *= procent
    print("Долг после", i, "года обучения: $", round(loan, 2))
print("Долг к концу обучения: $", round(loan, 2))
# Out:
# Долг после 1 года обучения: $ 127200.0
# Долг после 2 года обучения: $ 134832.0
# Долг после 3 года обучения: $ 142921.92
# Долг после 4 года обучения: $ 151497.24
# Долг после 5 года обучения: $ 160587.07
# Долг после 6 года обучения: $ 170222.29
# Долг к концу обучения: $ 170222.29

# %% [markdown]
# 3. Вспомним задачку о [зёрнах на шахматной доске](https://ru.wikipedia.org/wiki/%D0%97%D0%B0%D0%B4%D0%B0%D1%87%D0%B0_%D0%BE_%D0%B7%D1%91%D1%80%D0%BD%D0%B0%D1%85_%D0%BD%D0%B0_%D1%88%D0%B0%D1%85%D0%BC%D0%B0%D1%82%D0%BD%D0%BE%D0%B9_%D0%B4%D0%BE%D1%81%D0%BA%D0%B5). На первую клетку кладётся одно зерно, на вторую — два зерна, на третью — четыре, затем — восемь. С каждой клеткой количество зёрен увеличивается в два раза.
#
# Напишите цикл, который выводил бы на печать порядковый номер клетки и количество зёрен на ней до тех пор, пока их количество на одной клетке не превысит 100 тысяч.

# %%
cntGrain = 1
cntCell = 1
while cntGrain < 100000:
    cntGrain *= 2
    cntCell += 1
    print ("На", cntCell, "клетке лежит", cntGrain)
print("Остановка цикла на", cntCell, "клетке. Количество зерен", cntGrain, "превысило 100000")
# Out:
# На 2 клетке лежит 2
# На 3 клетке лежит 4
# На 4 клетке лежит 8
# На 5 клетке лежит 16
# На 6 клетке лежит 32
# На 7 клетке лежит 64
# На 8 клетке лежит 128
# На 9 клетке лежит 256
# На 10 клетке лежит 512
# На 11 клетке лежит 1024
# На 12 клетке лежит 2048
# На 13 клетке лежит 4096
# На 14 клетке лежит 8192
# На 15 клетке лежит 16384
# На 16 клетке лежит 32768
# На 17 клетке лежит 65536
# На 18 клетке лежит 131072
# Остановка цикла на 18 клетке. Количество зерен 131072 превысило 100000

# %% [markdown]
# 4. Напишите программу, которая проверяла бы все числа от 0 до 30. Если число делится на два, его нужно напечатать. Но если число делится и на четыре, его нужно пропустить.

# %%
for i in range(31):
    if i % 2 == 0:
        if i % 4 == 0:
            continue
        else:
            print("число", i, "делится на 2, но не делится на 4")
    else:
        pass
# Out:
# число 2 делится на 2, но не делится на 4
# число 6 делится на 2, но не делится на 4
# число 10 делится на 2, но не делится на 4
# число 14 делится на 2, но не делится на 4
# число 18 делится на 2, но не делится на 4
# число 22 делится на 2, но не делится на 4
# число 26 делится на 2, но не делится на 4
# число 30 делится на 2, но не делится на 4

# %%
# второй варинта
for i in range(31):
    if i % 2 == 0:
        if i % 4 != 0:
            print("число", i, "делится на 2, но не делится на 4")
# Out:
# число 2 делится на 2, но не делится на 4
# число 6 делится на 2, но не делится на 4
# число 10 делится на 2, но не делится на 4
# число 14 делится на 2, но не делится на 4
# число 18 делится на 2, но не делится на 4
# число 22 делится на 2, но не делится на 4
# число 26 делится на 2, но не делится на 4
# число 30 делится на 2, но не делится на 4

# %% [markdown]
# 5. Напишите программу, которая бесконечно запрашивает на ввод целое число. Если оно делится на три, то выводится на печать. Если делится на пять, то  на печать выводится его квадрат. Квадрат пишется даже для тех чисел, которые делятся на три. Если число делится на семь, нужно вывести на печать «дурак совсем» и прервать выполнение программы. Во всех остальных случаях программа должна снова запросить число на ввод.

# %%
while True:
    i = int(input("Введите целое число:"))
    if i % 7 == 0:
        print("дурак совсем :)")
        break
    elif i % 5 == 0:
        pass
    elif i % 3 == 0:
        print("Ваше число:", i, end = " - ")
    print("в квадрате:", i ** 2)
# Out:
# Ваше число: 3 - в квадрате: 9
# Ваше число: 9 - в квадрате: 81
# Ваше число: 6 - в квадрате: 36
# Ваше число в квадрате: 308025
# Ваше число в квадрате: 3025
# Ваше число в квадрате: 2500
# Ваше число в квадрате: 15625
# дурак совсем :)
