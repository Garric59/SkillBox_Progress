# %% [markdown]
# 1. Напишите программу «Военкомат», которая проверяет, подлежит ли человек призыву или нет по российским законам. Пусть программа запрашивает пол и возраст. Если это мужчина от 18 до 27 лет, программа должна выводить сообщение «Подлежит призыву!», во всех остальных случаях — выводить «Не подлежит призыву!».

# %%
# Программа "Военкомат"
age = 
sex = 

# Проверка

# %% [markdown]
# 2. Есть разные мнения, что считать юбилеем. В этой задаче будем называть юбилеем даты, кратные 10 годам. Напишите программу, которая спрашивает, сколько лет исполняется человеку, и сохраняет это число. Если дата круглая (делится на 10 без остатка), пусть программа выводит поздравление с юбилеем. Если не круглая — пусть программа просто поздравляет с днём рождения.

# %%
# Запрашиваем, сколько человеку исполняется лет

# Проверяем деление на 10 и выводим поздравление
